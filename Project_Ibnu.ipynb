# %% [markdown]
# # <font color = "green"> Python Image Processing</font>

# %% [markdown]
# ## <font color="red">Project Ibnu</font>
# ## <font color="blue">Using Pillow (PIL) Module</font>

# %%
from PIL import Image

img = Image.open('./cuci tangan.png')

img.show()

# %% [markdown]
# ## <font color="red">Project Ibnu 1</font>
# ## <font color="blue">Using Pillow (PIL) with matplotlib Module</font>

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open('./cuci tangan.png')

img.show()

plt.imshow(img)
